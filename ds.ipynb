# %% [markdown]
# ### Bernardo, Eric, Pedro e Victor

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading Dataset

# %%
path = "./ABR.xlsx"
df = pd.read_excel(path)

# %%
##df = df.drop(df.columns[[1,2,3,4,5,6,8,9,10,11,12,13,14,15]], axis=1)

df.plot(x = 'DT_MEAMB', y = 'QT_MEAMB')
plt.show()

df.head()
# Out:
#                   DT_MEAMB                                           NM_EMPMA  \
# 0  2020-04-01 00:05:00.000  SMAC - PCRJ PREFEITURA DA CIDADE DO RIO DE JAN...
# 1  2020-04-01 00:05:00.000  SMAC - PCRJ PREFEITURA DA CIDADE DO RIO DE JAN...
# 2  2020-04-01 00:05:00.000  SMAC - PCRJ PREFEITURA DA CIDADE DO RIO DE JAN...
# 3  2020-04-01 00:05:00.000  SMAC - PCRJ PREFEITURA DA CIDADE DO RIO DE JAN...
# 4  2020-04-01 00:05:00.000  SMAC - PCRJ PREFEITURA DA CIDADE DO RIO DE JAN...
#
#                    NM_ENTID         DS_OHATM     NM_MATER  \
# 0         Auto - SMAC_Iraja  Qualidade do Ar  Ar Ambiente
# 1  Auto - SMAC_Campo Grande  Qualidade do Ar  Ar Ambiente
# 2        Auto - SMAC_Centro  Qualidade do Ar  Ar Ambiente
# 3    Auto - SMAC_Copacabana  Qualidade do Ar  Ar Ambiente
# 4        Auto - SMAC_Centro  Qualidade do Ar  Ar Ambiente
#
#                        NM_PRHAT NM_PRHAT_ABRV  CD_EMPMA  \
# 0          Óxidos de Nitrogênio           NOx      1571
# ...
